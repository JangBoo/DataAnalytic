# %%
import pandas as pd
import numpy as np
df_SN7577 = pd.read_csv("tips.csv", sep=',')

# %%
df_SN7577
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             1       16.99  1.01  Female     No   Sun  Dinner     2
# 1             2       10.34  1.66    Male     No   Sun  Dinner     3
# 2             3       21.01  3.50    Male     No   Sun  Dinner     3
# 3             4       23.68  3.31    Male     No   Sun  Dinner     2
# 4             5       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         240       29.03  5.92    Male     No   Sat  Dinner     3
# 240         241       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         242       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         243       17.82  1.75    Male     No   Sat  Dinner     2
# 243         244       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
print(df_SN7577[['size']])
# Out:
#      size
# 0       2
# 1       3
# 2       3
# 3       2
# 4       4
# ..    ...
# 239     3
# 240     2
# 241     2
# 242     2
# 243     2
#
# [244 rows x 1 columns]

# %%
tip_rate= 0.18-0.01*df_SN7577[['size']]

# %%
tip_rate
# Out:
#      size
# 0    0.16
# 1    0.15
# 2    0.15
# 3    0.16
# 4    0.14
# ..    ...
# 239  0.15
# 240  0.16
# 241  0.16
# 242  0.16
# 243  0.16
#
# [244 rows x 1 columns]

# %%
df_all_rows = pd.concat([df_SN7577, tip_rate],axis = 1)
df_all_rows.columns =['index', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
       'size', 'tip_Rate']
df_all_rows
# Out:
#      index  total_bill   tip     sex smoker   day    time  size  tip_Rate
# 0        1       16.99  1.01  Female     No   Sun  Dinner     2      0.16
# 1        2       10.34  1.66    Male     No   Sun  Dinner     3      0.15
# 2        3       21.01  3.50    Male     No   Sun  Dinner     3      0.15
# 3        4       23.68  3.31    Male     No   Sun  Dinner     2      0.16
# 4        5       24.59  3.61  Female     No   Sun  Dinner     4      0.14
# ..     ...         ...   ...     ...    ...   ...     ...   ...       ...
# 239    240       29.03  5.92    Male     No   Sat  Dinner     3      0.15
# 240    241       27.18  2.00  Female    Yes   Sat  Dinner     2      0.16
# 241    242       22.67  2.00    Male    Yes   Sat  Dinner     2      0.16
# 242    243       17.82  1.75    Male     No   Sat  Dinner     2      0.16
# 243    244       18.78  3.00  Female     No  Thur  Dinner     2      0.16
#
# [244 rows x 9 columns]

# %%
df_SN7577_some_rows = df_all_rows.tip

df_SN7577_some_rows
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
#df_SN7577_some_rows.plot(kind='bar')
#plt.bar(range(len(df_SN7577_some_rows)), df_SN7577_some_rows,width = 10)
#plt.show()

plt.hist(df_SN7577_some_rows, bins=np.arange(min(df_SN7577_some_rows), max(df_SN7577_some_rows) + 1, 1))
plt.show()

# %%
plt.hist(df_SN7577_some_rows, bins=np.arange(min(df_SN7577_some_rows), max(df_SN7577_some_rows) +0.1, 0.1))
plt.show()

# %%
x1 = df_all_rows.total_bill
y1 = df_all_rows.tip


# Add some features
plt.title('Scatter Plot')
plt.ylabel('tip')
plt.xlabel('total_bill')



# plot the points in a scatter plot
plt.scatter(x1,y1, c='black' )  # 'c' parameter is the colour and 'label' is the text for the legend
y=x1
plt.plot(x1,x1*0.16)

plt.show()

# %%
#female no
df_all_rows.columns =['index', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
       'size', 'tip_Rate']

Female_no = df_all_rows[ (df_all_rows.sex == 'Female') & (df_all_rows.smoker== 'No')][['total_bill', 'tip']]
Female_yes = df_all_rows[ (df_all_rows.sex == 'Female') & (df_all_rows.smoker== 'Yes')][['total_bill', 'tip']]
male_no = df_all_rows[ (df_all_rows.sex == 'Male') & (df_all_rows.smoker== 'No')][['total_bill', 'tip']]
male_yes = df_all_rows[ (df_all_rows.sex == 'Male') & (df_all_rows.smoker== 'Yes')][['total_bill', 'tip']]

# %%
fig = plt.figure(figsize=(30,20))

plt.subplot(2, 2, 1)
plt.scatter(Female_no.total_bill, Female_no.tip)
x=Female_no.total_bill
y=x*0.16
plt.plot(x,y)

plt.subplot(2, 2, 2)
plt.scatter(male_no.total_bill, male_no.tip)
x=male_no.total_bill
y=x*0.16
plt.plot(x,y)

plt.subplot(2, 2, 3)
plt.scatter(Female_yes.total_bill, Female_yes.tip)
x=Female_yes.total_bill
y=x*0.16
plt.plot(x,y)

plt.subplot(2, 2, 4)
plt.scatter(male_yes.total_bill, male_yes.tip)
x=male_yes.total_bill
y=x*0.16
plt.plot(x,y)

plt.show()
